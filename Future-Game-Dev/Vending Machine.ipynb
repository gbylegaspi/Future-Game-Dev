# %% [markdown]
# <a href="https://colab.research.google.com/github/gbylegaspi/Future-Game-Dev/blob/main/Future-Game-Dev/Vending%20Machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This are the list of items in the vending machine
#Here you can see the code, The item name adn the price of the item

items = [
    {
        'code':0,
        'name':'Sprite',
        'price':3
    },
    {
        'code':1,
        'name':'KitKat',
        'price':10
    },
    {
        'code':2,
        'name':'Cheetos',
        'price':6.50
    },
    {
        'code':3,
        'name':'Water',
        'price':2
    },
    {
        'code':4,
        'name':'Doritos',
        'price':3
    },
    {
        'code':5,
        'name':'Red Bull',
        'price':12
    },
    {
        'code':6,
        'name':'Lays',
        'price':6.50
    },
    {
        'code':7,
        'name':'Mountain Dew',
        'price':5
    },
    {
        'code':8,
        'name':'Takis',
        'price':6.50
    },
    {
        'code':9,
        'name':'Coke',
        'price':5
    },
    {
        'code':10,
        'name':'Bounty',
        'price':3
    },
    {
        'code':11,
        'name':'Pepsi',
        'price':3
    },
    {
        'code':12,
        'name':'Pringles',
        'price':6.50
    },
    {
        'code':13,
        'name':'Fanta',
        'price':3
    },
]

# Here I made a separate dictionary for drinks and snacks
# This is so that when the user is asked to chooses between drinks or snacks
# The program will know which dictionary / menu to present to the user

drinks = [
    {
        'code':0,
        'name':'Sprite',
        'price':3
    },
    {
        'code':3,
        'name':'Water',
        'price':2
    },
    {
        'code':5,
        'name':'Red Bull',
        'price':12
    },
    {
        'code':7,
        'name':'Mountain Dew',
        'price':5
    },
    {
        'code':9,
        'name':'Coke',
        'price':5
    },
    {
        'code':11,
        'name':'Pepsi',
        'price':3
    },
    {
        'code':13,
        'name':'Fanta',
        'price':3
    },
]

snacks = [
    {
        'code':1,
        'name':'KitKat',
        'price':10
    },
    {
        'code':2,
        'name':'Cheetos',
        'price':6.50
    },
    {
        'code':4,
        'name':'Doritos',
        'price':3
    },
    {
        'code':6,
        'name':'Lays',
        'price':6.50
    },
    {
        'code':8,
        'name':'Takis',
        'price':6.50
    },
    {
        'code':10,
        'name':'Bounty',
        'price':3
    },
    {
        'code':12,
        'name':'Pringles',
        'price':6.50
    },
]

is_quit = False
item = ''

#Here is the line of code where the scripts welcoms the user to the vending machine
#And prints the dictionary/list of food and the prices as well as the code of the item

while is_quit == False:
    print("Welcome to the vending machine")
    break

#Here you can see the program is asking the user to enter the code of the item

food_type= str(input("\nEnter snacks or drinks to choose the item you want: ")).lower()
if food_type == 'snacks':
  print('\nSNACKS : \n')

  for i in snacks:
        print(f"Item Name: {i['name']} - Price: {i['price']} - code: {i['code']}")

  query = int(input("Enter the code number of the item you want to get: "))
  for i in items:
        if query == i['code']:
            item = i
            print(f"Great, {item['name']} will cost you {item['price']} dollars")

            print(f"Insert", item['price'], "AED into the vending machine: ")
            money = int(input())
            if money == item['price']:
              print(f"Thank you for buying here is your {item['name']}")
            elif money > item['price']:
              print(f"Here is your change" ,money - item['price'], "dollars.")
              print(f"Thank you for buying here is your {item['name']}")
if food_type == 'drinks':
  print('\nDRINKS : \n')

  for i in drinks:
        print(f"Item Name: {i['name']} - Price: {i['price']} - code: {i['code']}")

  query = int(input("Enter the code number of the item you want to get: "))
  for i in items:
        if query == i['code']:
            item = i
            print(f"Great, {item['name']} will cost you {item['price']} dollars")

            print(f"Insert", item['price'], "AED into the vending machine: ")
            money = int(input())
            if money == item['price']:
              print(f"Thank you for buying here is your {item['name']}")
            elif money > item['price']:
              print(f"Here is your change" ,money - item['price'], "dollars.")
              print(f"Thank you for buying here is your {item['name']}")
#And here I included "invalid code" for when if the user inputs a code that is not in the dictionary
#It will print "INVALID CODE"
#The program then tells the user the price of the item that he selected
#And then the program asks the user to enter the amount of money

  if item == '':
        print('INVALID CODE')

#Here you can see an option to end the program if the user does not want to buy anything else
#Or the user can type c to continue buying or q to quit

  query = input("To quit the machine enter q and to continue buying enter c: ").lower()
  if query == 'c':
        is_quit = False
  else:
        is_quit = True
        print('')
# Out:
# Welcome to the vending machine
#
# Enter snacks or drinks to choose the item you want: drinks
#
# DRINKS :
#
# Item Name: Sprite - Price: 3 - code: 0
# Item Name: Water - Price: 2 - code: 3
# Item Name: Red Bull - Price: 12 - code: 5
# Item Name: Mountain Dew - Price: 5 - code: 7
# Item Name: Coke - Price: 5 - code: 9
# Item Name: Pepsi - Price: 3 - code: 11
# Item Name: Fanta - Price: 3 - code: 13
# Enter the code number of the item you want to get: 13
# Great, Fanta will cost you 3 dollars
# Insert 3 AED into the vending machine:
# 50
# Here is your change 47 dollars.
# Thank you for buying here is your Fanta
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-19c9172a6f04> in <module>
#     213 #Or the user can type c to continue buying or q to quit
#     214
# --> 215   query = input("To quit the machine enter q and to continue buying enter c: ").lower()
# ...
